# %% [markdown]
# # BELINDA GRACE ABA ABOKUMA OTOO
# # 10971979
# # BIOMEDICAL ENGINEERING DEPARTMENT

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
print('Libraries imported successfully')
# Out:
# Libraries imported successfully

# %%
dt = pd.read_csv('data.csv')

# %%
dt
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
dt.columns = dt.columns.str.replace(' ','_')

# %%
dt
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed_acidity         1600 non-null   float64
#  2   volatile_acidity      1601 non-null   float64
#  3   citric_acid           1600 non-null   float64
#  4   residual_sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free_sulfur_dioxide   1600 non-null   float64
#  7   total_sulfur_dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
dt.isnull().sum()
# Out:
# ID                      0
# fixed_acidity           1
# volatile_acidity        0
# citric_acid             1
# residual_sugar          0
# chlorides               3
# free_sulfur_dioxide     1
# total_sulfur_dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
dt_mean_values = dt.mean()

# %%
dt_mean_values
# Out:
# ID                      801.000000
# fixed_acidity             8.319875
# volatile_acidity          0.527742
# citric_acid               0.271175
# residual_sugar            2.538445
# chlorides                 0.087487
# free_sulfur_dioxide      15.886875
# total_sulfur_dioxide     46.520000
# density                   0.996746
# pH                        3.311106
# sulphates                 0.658220
# alcohol                  10.423204
# quality                   5.636250
# dtype: float64

# %%
dt.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Replacing all null values with the mean of each column and removing all duplicates
#
# We can fill null values with the mean, median or model of the respective column using the fillna() method. This is a common approach and is useful when there are only a few null values in the dataset just like this dataset which we will be using the mean value and the drop_duplicate
# () method drop all duplicates in the dataset.

# %%
dt = dt.fillna(dt_mean_values).drop_duplicates()

# %%
dt
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %% [markdown]
#  The describe() method shows you the count, mean, standard deviation ,minimum and maximum values of dataset or individual columns

# %%
dt.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %%
meanFA=dt.fixed_acidity.mean()
meanVA=dt.volatile_acidity.mean()
meanCA=dt.citric_acid.mean()
meanRS=dt.residual_sugar.mean()
meanC=dt.chlorides.mean()
meanFSD=dt.free_sulfur_dioxide.mean()
meanTSD=dt.total_sulfur_dioxide.mean()
meanD=dt.density.mean()
meanPH=dt.pH.mean()
meanS=dt.sulphates.mean()
meanA=dt.alcohol.mean()
meanQ=dt.quality.mean()

# %%
print(f'This is the mean quality: {meanQ}')
print(f'This is the mean alcohol: {meanA}')
print(f'This is the mean sulphates: {meanS}')
print(f'This is the mean pH: {meanPH}')
print(f'This is the mean density: {meanD}')
print(f'This is the mean total sulfur dioxide: {meanTSD}')
print(f'This is the mean quality free sulfur dioxide: {meanFSD}')
print(f'This is the mean quality chlorides: {meanC}')
print(f'This is the mean quality residual sugar: {meanRS}')
print(f'This is the mean quality citric acid: {meanCA}')
print(f'This is the mean quality volatile acidity: {meanVA}')
print(f'This is the mean quality fixed acidty: {meanFA}')
# Out:
# This is the mean quality: 5.6362499999999995
# This is the mean alcohol: 10.42320424734541
# This is the mean sulphates: 0.6582198625858838
# This is the mean pH: 3.3111062500000004
# This is the mean density: 0.9967456437500001
# This is the mean total sulfur dioxide: 46.52
# This is the mean quality free sulfur dioxide: 15.886875
# This is the mean quality chlorides: 0.0874874843554443
# This is the mean quality residual sugar: 2.5384447220487196
# This is the mean quality citric acid: 0.27117500000000005
# This is the mean quality volatile acidity: 0.5277420362273579
# This is the mean quality fixed acidty: 8.319875

# %% [markdown]
# ### Histogram of columns in the dataset

# %%
#Histogram of columns
sns.histplot(data=dt, x=dt.fixed_acidity)
# Out:
# <Axes: xlabel='fixed_acidity', ylabel='Count'>

# %%
#Histogram of columns
sns.histplot(data=dt, x=dt.density)
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %%
#Histogram of columns
sns.histplot(data=dt, x=dt.pH)
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
#Histogram of columns
sns.histplot(data=dt, x=dt.alcohol)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# ### Pie chart of the columns in the dataset

# %%
# Creating a pie chart  for our cleaned up data
colors = ['orange', 'violet', 'yellow', 'brown', 'red', 'purple',
          'pink', 'black', 'gray', 'blue', 'violet', 'cyan']
explode = (0.5,0.5,1,1,1,0,0,0.5,0,0.5,0,0.5)
meanValues = [meanFA, meanVA, meanCA, meanRS, meanC,
              meanFSD, meanTSD, meanD, meanPH, meanS, meanA, meanQ]
meanTopics = ['FA',
              'VA',
              'CA',
              'RS',
              'C',
              'FSD',
              'TSD',
              'density',
              'pH',
              'sulphates',
              'alcohol',
              'quality']



labels = meanTopics
sizes = meanValues

legendLabels = ['fixed_acidity (FA)',
              'volatile_acidity (VA)',
              'citric_acid (CA)',
              'residual_sugar (RS)',
              'chlorides (C)',
              'free_sulfur_dioxide (FSD)',
              'total_sulfur_dioxide (TSD)',
              'density',
              'pH',
              'sulphates',
              'alcohol',
              'quality']

# %%
# plotting the pie chart
plt.pie(sizes, labels=labels, explode=explode,
        autopct='%1.1f%%', pctdistance=1.01, shadow=True, colors=colors, labeldistance=1.2)
plt.axis('equal')
plt.legend(title='index',labels=legendLabels)
plt.title('Mean Values for each of the columns in a pie chart')
plt.figure(figsize=(25,25))
plt.show()

# %% [markdown]
# ### Bar graph of the columns in the dataset

# %%
xtitle = 'Column names'
ytitle = 'Mean Values'
legendLabels = ['fixed_acidity (FA)',
              'volatile_acidity (VA)',
              'citric_acid (CA)',
              'residual_sugar (RS)',
              'chlorides (C)',
              'free_sulfur_dioxide (FSD)',
              'total_sulfur_dioxide (TSD)',
              'density',
              'pH',
              'sulphates',
              'alcohol',
              'quality']

# %%
labels = meanTopics
sizes = meanValues

# %%
# plotting a bar graph using the means as our data

fig = plt.figure(figsize=(10, 5))

plt.bar(labels, sizes, width=0.5, color=colors)
plt.xlabel(xtitle)
plt.ylabel(ytitle)
plt.title('Comparing mean of columns in a bar chart')
plt.legend( loc='upper right', )
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Drawing a heatmap using the correlations,we set our values to 1 dp so we can see our values clearly
dt_corr=dt.corr()
sns.heatmap(dt_corr, annot=True,fmt='0.1g')
# Out:
# <Axes: >
